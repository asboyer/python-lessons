# %%
# stack over flow data
import pandas as pd

# %%
df = pd.read_csv('../data/survey_results_public.csv')

# %%
df.head(10)
# Out:
#    Respondent                                         MainBranch Hobbyist  \
# 0           1                     I am a developer by profession      Yes
# 1           2                     I am a developer by profession       No
# 2           3                        I code primarily as a hobby      Yes
# 3           4                     I am a developer by profession      Yes
# 4           5  I used to be a developer by profession, but no...      Yes
# 5           6                     I am a developer by profession       No
# 6           7                     I am a developer by profession      Yes
# 7           8                     I am a developer by profession      Yes
# 8           9                     I am a developer by profession       No
# 9          10                     I am a developer by profession      Yes
#
#     Age Age1stCode CompFreq  CompTotal  ConvertedComp             Country  \
# 0   NaN         13  Monthly        NaN            NaN             Germany
# ...

# %%
df.tail(10)
# Out:
#        Respondent MainBranch Hobbyist  Age Age1stCode CompFreq  CompTotal  \
# 64451       64104        NaN      Yes  NaN         19      NaN        NaN
# 64452       64236        NaN      Yes  NaN        NaN      NaN        NaN
# 64453       64330        NaN      Yes  NaN          5      NaN        NaN
# 64454       64480        NaN      Yes  NaN         21      NaN        NaN
# 64455       64567        NaN      Yes  NaN        NaN      NaN        NaN
# 64456       64858        NaN      Yes  NaN         16      NaN        NaN
# 64457       64867        NaN      Yes  NaN        NaN      NaN        NaN
# 64458       64898        NaN      Yes  NaN        NaN      NaN        NaN
# 64459       64925        NaN      Yes  NaN        NaN      NaN        NaN
# 64460       65112        NaN      Yes  NaN        NaN      NaN        NaN
#
#        ConvertedComp        Country CurrencyDesc  ... SurveyEase SurveyLength  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64461 entries, 0 to 64460
# Data columns (total 61 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Respondent                    64461 non-null  int64
#  1   MainBranch                    64162 non-null  object
#  2   Hobbyist                      64416 non-null  object
#  3   Age                           45446 non-null  float64
#  4   Age1stCode                    57900 non-null  object
#  5   CompFreq                      40069 non-null  object
#  6   CompTotal                     34826 non-null  float64
#  7   ConvertedComp                 34756 non-null  float64
#  8   Country                       64072 non-null  object
#  9   CurrencyDesc                  45472 non-null  object
#  10  CurrencySymbol                45472 non-null  object
#  11  DatabaseDesireNextYear        44070 non-null  object
# ...

# %%
clean_df = df.dropna()

# %%
clean_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4213 entries, 9 to 63517
# Data columns (total 61 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Respondent                    4213 non-null   int64
#  1   MainBranch                    4213 non-null   object
#  2   Hobbyist                      4213 non-null   object
#  3   Age                           4213 non-null   float64
#  4   Age1stCode                    4213 non-null   object
#  5   CompFreq                      4213 non-null   object
#  6   CompTotal                     4213 non-null   float64
#  7   ConvertedComp                 4213 non-null   float64
#  8   Country                       4213 non-null   object
#  9   CurrencyDesc                  4213 non-null   object
#  10  CurrencySymbol                4213 non-null   object
#  11  DatabaseDesireNextYear        4213 non-null   object
# ...

# %%
clean_df.head()
# Out:
#     Respondent                      MainBranch Hobbyist   Age Age1stCode  \
# 9           10  I am a developer by profession      Yes  22.0         14
# 32          33  I am a developer by profession      Yes  39.0         14
# 41          42  I am a developer by profession       No  32.0         14
# 46          47  I am a developer by profession      Yes  53.0         10
# 68          69  I am a developer by profession      Yes  25.0         12
#
#    CompFreq  CompTotal  ConvertedComp         Country          CurrencyDesc  \
# 9    Yearly    25000.0        32315.0  United Kingdom        Pound sterling
# 32  Monthly     4900.0        63564.0         Belgium         European Euro
# 41   Yearly   130000.0       130000.0   United States  United States dollar
# 46   Yearly    58000.0        74970.0  United Kingdom        Pound sterling
# 68   Yearly   550000.0       594539.0          France         European Euro
#
#     ...                  SurveyEase           SurveyLength Trans  \
# ...

# %%
fill_df = df.copy()

# %%
fill_df.fillna("Not recorded", inplace=True)

# %%
fill_df
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1                     I am a developer by profession      Yes
# 1               2                     I am a developer by profession       No
# 2               3                        I code primarily as a hobby      Yes
# 3               4                     I am a developer by profession      Yes
# 4               5  I used to be a developer by profession, but no...      Yes
# ...           ...                                                ...      ...
# 64456       64858                                       Not recorded      Yes
# 64457       64867                                       Not recorded      Yes
# 64458       64898                                       Not recorded      Yes
# 64459       64925                                       Not recorded      Yes
# 64460       65112                                       Not recorded      Yes
#
# ...

# %%
df["Hobbyist"]
# Out:
# 0        Yes
# 1         No
# 2        Yes
# 3        Yes
# 4        Yes
#         ...
# 64456    Yes
# 64457    Yes
# 64458    Yes
# 64459    Yes
# 64460    Yes
# Name: Hobbyist, Length: 64461, dtype: object

# %%
cdf = df.copy()

# %%
cdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64461 entries, 0 to 64460
# Data columns (total 61 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Respondent                    64461 non-null  int64
#  1   MainBranch                    64162 non-null  object
#  2   Hobbyist                      64416 non-null  object
#  3   Age                           45446 non-null  float64
#  4   Age1stCode                    57900 non-null  object
#  5   CompFreq                      40069 non-null  object
#  6   CompTotal                     34826 non-null  float64
#  7   ConvertedComp                 34756 non-null  float64
#  8   Country                       64072 non-null  object
#  9   CurrencyDesc                  45472 non-null  object
#  10  CurrencySymbol                45472 non-null  object
#  11  DatabaseDesireNextYear        44070 non-null  object
# ...

# %%
cdf = cdf[cdf['YearsCode'].notna()] #drop values for specified column

# %%
cdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 46221 entries, 0 to 64456
# Data columns (total 61 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Respondent                    46221 non-null  int64
#  1   MainBranch                    46146 non-null  object
#  2   Hobbyist                      46221 non-null  object
#  3   Age                           36775 non-null  float64
#  4   Age1stCode                    46137 non-null  object
#  5   CompFreq                      39668 non-null  object
#  6   CompTotal                     34610 non-null  float64
#  7   ConvertedComp                 34542 non-null  float64
#  8   Country                       46221 non-null  object
#  9   CurrencyDesc                  44744 non-null  object
#  10  CurrencySymbol                44744 non-null  object
#  11  DatabaseDesireNextYear        33993 non-null  object
# ...

# %%
cdf["YearsCode"]
# Out:
# 0                      36
# 1                       7
# 3                       7
# 4                      15
# 5                       6
#                ...
# 64438    Less than 1 year
# 64446                   6
# 64447                   6
# 64449    Less than 1 year
# 64456                  10
# Name: YearsCode, Length: 46221, dtype: object

# %%
cdf["DatabaseDesireNextYear"].fillna("Does not work with Databases", inplace = True)

# %%
cdf["DatabaseDesireNextYear"]
# Out:
# 0                                     Microsoft SQL Server
# 1                             Does not work with Databases
# 3                             Does not work with Databases
# 4                                         MySQL;PostgreSQL
# 5                             Does not work with Databases
#                                ...
# 64438                         Elasticsearch;IBM DB2;Oracle
# 64446    Firebase;Microsoft SQL Server;MongoDB;MySQL;Po...
# 64447                         Does not work with Databases
# 64449                         Does not work with Databases
# 64456                         Does not work with Databases
# Name: DatabaseDesireNextYear, Length: 46221, dtype: object

# %%
x = df["Age"].mean()

# %%
x
# Out:
# 30.83411081283281

# %%
df["Age1stCode"].mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-82-52dc10429725> in <module>
# ----> 1 df["Age1stCode"].mean()
#
# c:\python\python3.8\lib\site-packages\pandas\core\generic.py in mean(self, axis, skipna, level, numeric_only, **kwargs)
#   11116         )
#   11117         def mean(self, axis=None, skipna=None, level=None, numeric_only=None, **kwargs):
# > 11118             return NDFrame.mean(self, axis, skipna, level, numeric_only, **kwargs)
#   11119
#   11120         # pandas\core\generic.py:10924: error: Cannot assign to a method
#
# c:\python\python3.8\lib\site-packages\pandas\core\generic.py in mean(self, axis, skipna, level, numeric_only, **kwargs)
#   10724
#   10725     def mean(self, axis=None, skipna=None, level=None, numeric_only=None, **kwargs):
# > 10726         return self._stat_function(
# ...

# %%
df["Age1stCode"].mean()
# Out:
# 15.41727115716753

# %%
for i in df["Age1stCode"]:
    print(i)
# Out:
# 13
# 19
# 15
# 18
# 16
# 14
# 18
# 12
# 20
# 14
# 13
# 42
# 14
# 13
# 13
# 8
# 14
# 12
# 15
# 18
# 16
# 18
# 14
# 14
# 25
# 12
# 12
# 22
# 15
# 14
# 20
# 12
# 14
# 15
# 13
# 30
# 16
# 14
# 17
# 14
# 15
# 14
# 16
# 21
# 13
# 14
# 10
# 30
# 15
# 46
# 10
# 15
# 9
# 7
# 20
# 21
# 12
# 22
# 15
# 14
# 12
# 11
# 17
# 12
# 13
# 9
# 6
# 10
# 12
# 19
# 15
# 16
# 12
# 8
# nan
# 10
# 6
# 14
# 17
# 11
# 14
# 11
# 17
# 12
# 15
# 10
# 17
# 14
# 12
# 25
# 11
# 12
# 12
# 12
# 21
# 13
# 15
# 7
# 8
# 20
# 10
# 15
# 16
# 16
# 12
# 13
# 30
# 11
# 11
# 20
# 16
# 12
# 7
# 14
# 13
# 11
# 11
# 15
# 15
# 19
# 12
# 12
# 14
# 30
# 11
# 15
# 14
# 16
# 15
# 11
# 13
# 18
# 10
# 10
# 12
# 17
# 18
# 17
# 13
# 16
# 25
# 10
# 14
# 11
# 12
# 15
# 13
# 31
# 12
# 10
# 16
# 16
# 12
# 10
# 16
# 15
# 18
# 12
# 8
# 14
# 10
# 13
# 14
# 12
# 9
# 15
# 14
# 29
# 17
# 12
# 14
# 13
# 12
# 19
# 12
# 18
# 19
# 16
# 20
# 11
# 11
# nan
# 10
# 11
# 25
# 12
# 14
# 15
# 20
# 14
# 18
# 16
# 14
# 13
# 15
# 14
# 8
# 5
# 9
# 18
# 16
# 13
# ...

# %%
df["Age1stCode"] = df["Age1stCode"].replace("Younger than 5 years", value="5")
df["Age1stCode"] = df["Age1stCode"].replace("Older than 85", value="85")

# %%
for i in df["Age1stCode"]:
    print(i)
# Out:
# 13
# 19
# 15
# 18
# 16
# 14
# 18
# 12
# 20
# 14
# 13
# 42
# 14
# 13
# 13
# 8
# 14
# 12
# 15
# 18
# 16
# 18
# 14
# 14
# 25
# 12
# 12
# 22
# 15
# 14
# 20
# 12
# 14
# 15
# 15
# 18
# 12
# 8
# 14
# 10
# 13
# 14
# 12
# 9
# 15
# 14
# 29
# 17
# 12
# 14
# 13
# 12
# 19
# 12
# 18
# 19
# 16
# 20
# 11
# 11
# nan
# 10
# 11
# 25
# 12
# 14
# 15
# 20
# 14
# 18
# 16
# 14
# 13
# 15
# 14
# 8
# 5
# 9
# 18
# 16
# 13
# ...

# %%
df["Age1stCode"].fillna(x, inplace=True)

# %%
df["Age1stCode"]
# Out:
# 0               13
# 1               19
# 2               15
# 3               18
# 4               16
#            ...
# 64456           16
# 64457    15.417271
# 64458    15.417271
# 64459    15.417271
# 64460    15.417271
# Name: Age1stCode, Length: 64461, dtype: object

# %%
for i in df["YearsCode"]:
    print(i)
# Out:
# 36
# 7
# 4
# 7
# 15
# 6
# 6
# 17
# 6
# 8
# 10
# 7
# 35
# 5
# 4
# 37
# 7
# 19
# 9
# 22
# 7
# 10
# 8
# 30
# 23
# 17
# 20
# 2
# Less than 1 year
# 4
# 6
# 19
# 20
# 10
# 3
# 4
# 2
# 20
# 13
# 6
# 25
# 16
# 36
# 10
# 9
# 6
# 43
# 8
# 8
# 10
# 23
# 11
# 8
# 38
# 2
# 6
# 33
# nan
# 24
# 2
# 16
# 7
# 4
# 20
# 21
# 12
# 30
# 10
# 13
# 6
# 8
# 10
# 23
# 17
# nan
# 9
# 30
# 3
# 10
# 21
# 5
# 37
# 2
# 13
# 6
# 5
# 5
# 7
# 6
# 3
# 19
# 24
# 9
# 40
# 3
# 17
# 10
# 15
# 27
# 30
# 25
# 3
# 10
# 6
# 12
# 5
# 35
# 6
# 30
# 6
# 11
# 35
# 33
# 9
# 25
# 19
# 9
# 16
# 10
# 8
# 10
# 8
# 24
# 11
# 9
# 50
# 5
# 4
# 8
# 5
# 5
# 8
# 20
# 35
# 3
# 46
# 4
# 13
# 35
# 6
# 3
# 15
# 16
# 4
# 21
# 5
# 10
# 5
# 23
# 8
# 14
# 6
# 30
# 33
# 8
# 6
# 22
# 18
# 24
# 10
# 28
# 21
# 5
# 18
# 15
# 7
# 7
# 3
# 4
# 19
# 37
# 7
# 10
# 3
# 9
# 12
# 3
# 11
# 10
# 9
# 11
# nan
# 10
# 14
# 4
# 30
# 4
# 15
# 20
# 9
# 2
# 13
# 6
# 13
# 8
# 3
# 32
# 15
# 44
# 9
# 4
# 7
# 33
# 22
# 8
# 25
# 20
# 40
# 26
# 6
# 11
# 30
# 25
# 18
# 9
# ...

# %%
df["YearsCode"] = df["YearsCode"].replace("Less than 1 year", value="1")
df["YearsCode"] = df["YearsCode"].replace("More than 50 years", value="50")
x = df["YearsCode"].dropna().astype(int).mean()

# %%
x
# Out:
# 12.719696969696969

# %%
df["YearsCode"].fillna(x, inplace=True)

# %%
df["YearsCode"] = df["YearsCode"].astype(int)

# %%
df["YearsCode"].mean()
# Out:
# 12.644032826049859
